# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../data/" directory.
# will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../data/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ../data/train_image_data_2.parquet
# ../data/train_image_data_3.parquet
# ../data/train_image_data_1.parquet
# ../data/test.csv
# ../data/train_image_data_0.parquet
# ../data/test_image_data_1.parquet
# ../data/test_image_data_0.parquet
# ../data/train.csv
# ../data/test_image_data_2.parquet
# ../data/class_map.csv
# ../data/test_image_data_3.parquet
# ../data/sample_submission.csv
# ../data/kalpurush.ttf
# ../data/submission.csv

# %%
train_df_ = pd.read_csv('../data/train.csv')
test_df_ = pd.read_csv('../data/test.csv')
class_map_df = pd.read_csv('../data/class_map.csv')
sample_sub_df = pd.read_csv('../data/sample_submission.csv')

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
train_df_
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic
# 0            Train_0             15                9                    5
# 1            Train_1            159                0                    0
# 2            Train_2             22                3                    5
# 3            Train_3             53                2                    2
# 4            Train_4             71                9                    5
# 5            Train_5            153                9                    0
# 6            Train_6             52                2                    0
# 7            Train_7            139                3                    0
# 8            Train_8             67                0                    0
# 9            Train_9             64                7                    1
# 10          Train_10            115                1                    2
# 11          Train_11            107                0                    3
# 12          Train_12             74                1                    2
# 13          Train_13            100                1                    0
# 14          Train_14             48                4                    0
# 15          Train_15             72                2                    2
# 16          Train_16             13                3                    2
# 17          Train_17             79                4                    5
# 18          Train_18            109                3                    0
# 19          Train_19             23                7                    0
# 20          Train_20             42                0                    2
# 21          Train_21             60                4                    0
# 22          Train_22             53                4                    5
# 23          Train_23             22                0                    2
# 24          Train_24            142                0                    0
# 25          Train_25             61                1                    0
# 26          Train_26            147                1                    2
# 27          Train_27             81                8                    0
# 28          Train_28            148                6                    0
# 29          Train_29            160                0                    0
# ...              ...            ...              ...                  ...
# 200810  Train_200810            143                1                    0
# 200811  Train_200811            122                4                    0
# 200812  Train_200812            159                1                    5
# 200813  Train_200813             22                7                    2
# 200814  Train_200814            155                8                    0
# 200815  Train_200815             13                1                    0
# 200816  Train_200816             23                8                    0
# 200817  Train_200817             64                7                    5
# 200818  Train_200818            107                2                    5
# 200819  Train_200819            135                9                    0
# 200820  Train_200820             59                1                    4
# 200821  Train_200821            159                0                    4
# 200822  Train_200822             38                5                    4
# 200823  Train_200823             96                9                    2
# 200824  Train_200824            147                3                    0
# 200825  Train_200825            138                4                    0
# 200826  Train_200826            162                3                    0
# 200827  Train_200827            149                7                    0
# 200828  Train_200828             38                2                    0
# 200829  Train_200829             81                4                    0
# 200830  Train_200830             39                2                    0
# 200831  Train_200831             81                9                    2
# 200832  Train_200832             58                9                    0
# 200833  Train_200833            130                0                    0
# 200834  Train_200834            144                1                    5
# 200835  Train_200835             22                7                    2
# 200836  Train_200836             65                9                    0
# 200837  Train_200837              2                1                    4
# 200838  Train_200838            152                9                    0
# 200839  Train_200839            127                2                    0
#
# [200840 rows x 4 columns]

# %%
IMG_SIZE=64
N_CHANNELS=1

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0430 03:26:15.260549 140011596736320 deprecation.py:506] From /usr/lib/python3.6/site-packages/tensorflow/python/training/moving_averages.py:210: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0430 03:26:15.352350 140011596736320 deprecation.py:506] From /usr/lib64/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
#from keras.utils import plot_model
#plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'../data/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,  
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False, 
        #rotation_range=0,  
        #zoom_range = 0.0, 
        #width_shift_range=0.0,  
        #height_shift_range=0.0,  
        rotation_range=8,  # rotating images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally by a fraction of total width
        height_shift_range=0.15,  # randomly shift images vertically by a fraction of total height
        horizontal_flip=False,  
        vertical_flip=False)  


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 45s 251ms/step - loss: 7.9296 - dense_3_loss: 4.7690 - dense_4_loss: 1.9588 - dense_5_loss: 1.2018 - dense_3_acc: 0.0289 - dense_4_acc: 0.3014 - dense_5_acc: 0.6198 - val_loss: 6.9602 - val_dense_3_loss: 4.6273 - val_dense_4_loss: 1.2698 - val_dense_5_loss: 1.0632 - val_dense_3_acc: 0.0346 - val_dense_4_acc: 0.5873 - val_dense_5_acc: 0.6293
# Epoch 2/30
# /usr/lib64/python3.6/site-packages/keras/callbacks.py:1109: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_3_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/lib64/python3.6/site-packages/keras/callbacks.py:1109: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_4_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/lib64/python3.6/site-packages/keras/callbacks.py:1109: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 180/180 [==============================] - 40s 220ms/step - loss: 6.8134 - dense_3_loss: 4.5078 - dense_4_loss: 1.2928 - dense_5_loss: 1.0128 - dense_3_acc: 0.0430 - dense_4_acc: 0.5542 - dense_5_acc: 0.6495 - val_loss: 5.8774 - val_dense_3_loss: 4.2299 - val_dense_4_loss: 0.8216 - val_dense_5_loss: 0.8259 - val_dense_3_acc: 0.0545 - val_dense_4_acc: 0.7259 - val_dense_5_acc: 0.7055
# Epoch 3/30
# 180/180 [==============================] - 40s 223ms/step - loss: 6.1701 - dense_3_loss: 4.1888 - dense_4_loss: 1.0896 - dense_5_loss: 0.8917 - dense_3_acc: 0.0696 - dense_4_acc: 0.6257 - dense_5_acc: 0.6853 - val_loss: 5.1299 - val_dense_3_loss: 3.7344 - val_dense_4_loss: 0.6780 - val_dense_5_loss: 0.7175 - val_dense_3_acc: 0.1026 - val_dense_4_acc: 0.7757 - val_dense_5_acc: 0.7274
# Epoch 4/30
# 180/180 [==============================] - 42s 234ms/step - loss: 5.2991 - dense_3_loss: 3.6812 - dense_4_loss: 0.9011 - dense_5_loss: 0.7168 - dense_3_acc: 0.1248 - dense_4_acc: 0.6978 - dense_5_acc: 0.7496 - val_loss: 4.1310 - val_dense_3_loss: 3.0583 - val_dense_4_loss: 0.5578 - val_dense_5_loss: 0.5148 - val_dense_3_acc: 0.2036 - val_dense_4_acc: 0.8123 - val_dense_5_acc: 0.8195
# Epoch 5/30
# 180/180 [==============================] - 53s 295ms/step - loss: 4.2434 - dense_3_loss: 2.9618 - dense_4_loss: 0.7306 - dense_5_loss: 0.5510 - dense_3_acc: 0.2331 - dense_4_acc: 0.7588 - dense_5_acc: 0.8118 - val_loss: 3.0015 - val_dense_3_loss: 2.2808 - val_dense_4_loss: 0.4005 - val_dense_5_loss: 0.3202 - val_dense_3_acc: 0.3625 - val_dense_4_acc: 0.8678 - val_dense_5_acc: 0.8907
# Epoch 6/30
# 180/180 [==============================] - 57s 314ms/step - loss: 3.6923 - dense_3_loss: 2.4942 - dense_4_loss: 0.6988 - dense_5_loss: 0.4992 - dense_3_acc: 0.3278 - dense_4_acc: 0.7688 - dense_5_acc: 0.8322 - val_loss: 3.2298 - val_dense_3_loss: 2.2698 - val_dense_4_loss: 0.5210 - val_dense_5_loss: 0.4390 - val_dense_3_acc: 0.4262 - val_dense_4_acc: 0.8427 - val_dense_5_acc: 0.8686
# Epoch 7/30
# 180/180 [==============================] - 65s 361ms/step - loss: 3.4529 - dense_3_loss: 2.2920 - dense_4_loss: 0.6730 - dense_5_loss: 0.4880 - dense_3_acc: 0.3831 - dense_4_acc: 0.7780 - dense_5_acc: 0.8372 - val_loss: 2.1596 - val_dense_3_loss: 1.5294 - val_dense_4_loss: 0.3704 - val_dense_5_loss: 0.2598 - val_dense_3_acc: 0.5564 - val_dense_4_acc: 0.8875 - val_dense_5_acc: 0.9159
# Epoch 8/30
# 180/180 [==============================] - 64s 357ms/step - loss: 2.7989 - dense_3_loss: 1.8484 - dense_4_loss: 0.5490 - dense_5_loss: 0.4015 - dense_3_acc: 0.4852 - dense_4_acc: 0.8230 - dense_5_acc: 0.8658 - val_loss: 1.8304 - val_dense_3_loss: 1.2768 - val_dense_4_loss: 0.3009 - val_dense_5_loss: 0.2528 - val_dense_3_acc: 0.6241 - val_dense_4_acc: 0.9109 - val_dense_5_acc: 0.9211
# Epoch 9/30
# 180/180 [==============================] - 64s 356ms/step - loss: 2.6547 - dense_3_loss: 1.7147 - dense_4_loss: 0.5499 - dense_5_loss: 0.3901 - dense_3_acc: 0.5236 - dense_4_acc: 0.8221 - dense_5_acc: 0.8715 - val_loss: 1.5171 - val_dense_3_loss: 1.0596 - val_dense_4_loss: 0.2477 - val_dense_5_loss: 0.2098 - val_dense_3_acc: 0.6941 - val_dense_4_acc: 0.9196 - val_dense_5_acc: 0.9378
# Epoch 10/30
# 180/180 [==============================] - 68s 378ms/step - loss: 2.2616 - dense_3_loss: 1.4538 - dense_4_loss: 0.4718 - dense_5_loss: 0.3361 - dense_3_acc: 0.5932 - dense_4_acc: 0.8483 - dense_5_acc: 0.8886 - val_loss: 1.4199 - val_dense_3_loss: 0.9652 - val_dense_4_loss: 0.2394 - val_dense_5_loss: 0.2153 - val_dense_3_acc: 0.7187 - val_dense_4_acc: 0.9248 - val_dense_5_acc: 0.9288
# Epoch 11/30
# 180/180 [==============================] - 66s 368ms/step - loss: 1.9513 - dense_3_loss: 1.2289 - dense_4_loss: 0.4174 - dense_5_loss: 0.3049 - dense_3_acc: 0.6470 - dense_4_acc: 0.8668 - dense_5_acc: 0.8988 - val_loss: 1.2046 - val_dense_3_loss: 0.7966 - val_dense_4_loss: 0.2472 - val_dense_5_loss: 0.1608 - val_dense_3_acc: 0.7702 - val_dense_4_acc: 0.9350 - val_dense_5_acc: 0.9465
# Epoch 12/30
# 180/180 [==============================] - 68s 375ms/step - loss: 2.1561 - dense_3_loss: 1.3575 - dense_4_loss: 0.4680 - dense_5_loss: 0.3306 - dense_3_acc: 0.6199 - dense_4_acc: 0.8517 - dense_5_acc: 0.8918 - val_loss: 1.7652 - val_dense_3_loss: 1.2092 - val_dense_4_loss: 0.3039 - val_dense_5_loss: 0.2522 - val_dense_3_acc: 0.6507 - val_dense_4_acc: 0.9032 - val_dense_5_acc: 0.9183
# Epoch 13/30
# 180/180 [==============================] - 68s 377ms/step - loss: 1.9982 - dense_3_loss: 1.2482 - dense_4_loss: 0.4343 - dense_5_loss: 0.3157 - dense_3_acc: 0.6486 - dense_4_acc: 0.8643 - dense_5_acc: 0.8969 - val_loss: 1.2580 - val_dense_3_loss: 0.8333 - val_dense_4_loss: 0.2202 - val_dense_5_loss: 0.2045 - val_dense_3_acc: 0.7613 - val_dense_4_acc: 0.9340 - val_dense_5_acc: 0.9323
# Epoch 14/30
# 180/180 [==============================] - 68s 376ms/step - loss: 1.7372 - dense_3_loss: 1.0749 - dense_4_loss: 0.3879 - dense_5_loss: 0.2744 - dense_3_acc: 0.6932 - dense_4_acc: 0.8770 - dense_5_acc: 0.9093 - val_loss: 1.3388 - val_dense_3_loss: 0.9065 - val_dense_4_loss: 0.2275 - val_dense_5_loss: 0.2048 - val_dense_3_acc: 0.7473 - val_dense_4_acc: 0.9318 - val_dense_5_acc: 0.9390
# Epoch 15/30
# 180/180 [==============================] - 67s 375ms/step - loss: 1.5546 - dense_3_loss: 0.9507 - dense_4_loss: 0.3544 - dense_5_loss: 0.2494 - dense_3_acc: 0.7256 - dense_4_acc: 0.8879 - dense_5_acc: 0.9197 - val_loss: 0.9687 - val_dense_3_loss: 0.6177 - val_dense_4_loss: 0.1982 - val_dense_5_loss: 0.1528 - val_dense_3_acc: 0.8183 - val_dense_4_acc: 0.9452 - val_dense_5_acc: 0.9520
# Epoch 16/30
# 180/180 [==============================] - 66s 365ms/step - loss: 1.4054 - dense_3_loss: 0.8444 - dense_4_loss: 0.3303 - dense_5_loss: 0.2307 - dense_3_acc: 0.7567 - dense_4_acc: 0.8958 - dense_5_acc: 0.9244 - val_loss: 0.9345 - val_dense_3_loss: 0.5969 - val_dense_4_loss: 0.1937 - val_dense_5_loss: 0.1439 - val_dense_3_acc: 0.8307 - val_dense_4_acc: 0.9482 - val_dense_5_acc: 0.9557
# Epoch 17/30
# 180/180 [==============================] - 65s 362ms/step - loss: 1.3574 - dense_3_loss: 0.8161 - dense_4_loss: 0.3138 - dense_5_loss: 0.2275 - dense_3_acc: 0.7635 - dense_4_acc: 0.9014 - dense_5_acc: 0.9263 - val_loss: 0.8557 - val_dense_3_loss: 0.5676 - val_dense_4_loss: 0.1410 - val_dense_5_loss: 0.1471 - val_dense_3_acc: 0.8399 - val_dense_4_acc: 0.9607 - val_dense_5_acc: 0.9554
# Epoch 18/30
# 180/180 [==============================] - 65s 362ms/step - loss: 1.2931 - dense_3_loss: 0.7763 - dense_4_loss: 0.3018 - dense_5_loss: 0.2150 - dense_3_acc: 0.7742 - dense_4_acc: 0.9063 - dense_5_acc: 0.9311 - val_loss: 0.8365 - val_dense_3_loss: 0.5260 - val_dense_4_loss: 0.1796 - val_dense_5_loss: 0.1309 - val_dense_3_acc: 0.8554 - val_dense_4_acc: 0.9515 - val_dense_5_acc: 0.9577
# Epoch 19/30
# 180/180 [==============================] - 66s 369ms/step - loss: 1.2565 - dense_3_loss: 0.7444 - dense_4_loss: 0.3025 - dense_5_loss: 0.2096 - dense_3_acc: 0.7857 - dense_4_acc: 0.9055 - dense_5_acc: 0.9332 - val_loss: 0.8247 - val_dense_3_loss: 0.5191 - val_dense_4_loss: 0.1885 - val_dense_5_loss: 0.1172 - val_dense_3_acc: 0.8559 - val_dense_4_acc: 0.9500 - val_dense_5_acc: 0.9639
# Epoch 20/30
# 180/180 [==============================] - 66s 368ms/step - loss: 1.2615 - dense_3_loss: 0.7568 - dense_4_loss: 0.2960 - dense_5_loss: 0.2086 - dense_3_acc: 0.7811 - dense_4_acc: 0.9068 - dense_5_acc: 0.9324 - val_loss: 0.8465 - val_dense_3_loss: 0.5631 - val_dense_4_loss: 0.1493 - val_dense_5_loss: 0.1341 - val_dense_3_acc: 0.8467 - val_dense_4_acc: 0.9569 - val_dense_5_acc: 0.9592
# Epoch 21/30
# 180/180 [==============================] - 66s 366ms/step - loss: 1.1520 - dense_3_loss: 0.6765 - dense_4_loss: 0.2774 - dense_5_loss: 0.1981 - dense_3_acc: 0.8026 - dense_4_acc: 0.9135 - dense_5_acc: 0.9360 - val_loss: 0.7671 - val_dense_3_loss: 0.4775 - val_dense_4_loss: 0.1603 - val_dense_5_loss: 0.1294 - val_dense_3_acc: 0.8681 - val_dense_4_acc: 0.9567 - val_dense_5_acc: 0.9567
# Epoch 22/30
# 180/180 [==============================] - 66s 367ms/step - loss: 1.1744 - dense_3_loss: 0.6835 - dense_4_loss: 0.2922 - dense_5_loss: 0.1986 - dense_3_acc: 0.8010 - dense_4_acc: 0.9101 - dense_5_acc: 0.9340 - val_loss: 1.1498 - val_dense_3_loss: 0.7569 - val_dense_4_loss: 0.2149 - val_dense_5_loss: 0.1780 - val_dense_3_acc: 0.7929 - val_dense_4_acc: 0.9405 - val_dense_5_acc: 0.9447
# Epoch 23/30
# 180/180 [==============================] - 66s 366ms/step - loss: 1.1919 - dense_3_loss: 0.7103 - dense_4_loss: 0.2818 - dense_5_loss: 0.1997 - dense_3_acc: 0.7969 - dense_4_acc: 0.9126 - dense_5_acc: 0.9333 - val_loss: 0.7066 - val_dense_3_loss: 0.4731 - val_dense_4_loss: 0.1246 - val_dense_5_loss: 0.1089 - val_dense_3_acc: 0.8720 - val_dense_4_acc: 0.9671 - val_dense_5_acc: 0.9669
# Epoch 24/30
# 180/180 [==============================] - 66s 366ms/step - loss: 1.1105 - dense_3_loss: 0.6421 - dense_4_loss: 0.2741 - dense_5_loss: 0.1944 - dense_3_acc: 0.8126 - dense_4_acc: 0.9155 - dense_5_acc: 0.9370 - val_loss: 0.7896 - val_dense_3_loss: 0.5294 - val_dense_4_loss: 0.1405 - val_dense_5_loss: 0.1197 - val_dense_3_acc: 0.8561 - val_dense_4_acc: 0.9562 - val_dense_5_acc: 0.9599
# Epoch 25/30
# 180/180 [==============================] - 64s 354ms/step - loss: 1.2057 - dense_3_loss: 0.7028 - dense_4_loss: 0.2963 - dense_5_loss: 0.2066 - dense_3_acc: 0.7977 - dense_4_acc: 0.9089 - dense_5_acc: 0.9348 - val_loss: 0.6898 - val_dense_3_loss: 0.4433 - val_dense_4_loss: 0.1309 - val_dense_5_loss: 0.1155 - val_dense_3_acc: 0.8733 - val_dense_4_acc: 0.9607 - val_dense_5_acc: 0.9647
# Epoch 26/30
# 180/180 [==============================] - 65s 361ms/step - loss: 1.2198 - dense_3_loss: 0.6994 - dense_4_loss: 0.3080 - dense_5_loss: 0.2124 - dense_3_acc: 0.8005 - dense_4_acc: 0.9065 - dense_5_acc: 0.9331 - val_loss: 1.2303 - val_dense_3_loss: 0.8175 - val_dense_4_loss: 0.2436 - val_dense_5_loss: 0.1692 - val_dense_3_acc: 0.7884 - val_dense_4_acc: 0.9291 - val_dense_5_acc: 0.9500
# Epoch 27/30
# 180/180 [==============================] - 63s 350ms/step - loss: 1.1768 - dense_3_loss: 0.6733 - dense_4_loss: 0.2957 - dense_5_loss: 0.2078 - dense_3_acc: 0.8045 - dense_4_acc: 0.9089 - dense_5_acc: 0.9325 - val_loss: 1.1854 - val_dense_3_loss: 0.7624 - val_dense_4_loss: 0.2428 - val_dense_5_loss: 0.1802 - val_dense_3_acc: 0.8265 - val_dense_4_acc: 0.9440 - val_dense_5_acc: 0.9547
# Epoch 28/30
# 180/180 [==============================] - 67s 374ms/step - loss: 0.9843 - dense_3_loss: 0.5617 - dense_4_loss: 0.2509 - dense_5_loss: 0.1718 - dense_3_acc: 0.8365 - dense_4_acc: 0.9235 - dense_5_acc: 0.9448 - val_loss: 0.8960 - val_dense_3_loss: 0.6111 - val_dense_4_loss: 0.1669 - val_dense_5_loss: 0.1180 - val_dense_3_acc: 0.8444 - val_dense_4_acc: 0.9527 - val_dense_5_acc: 0.9617
# Epoch 29/30
# 180/180 [==============================] - 62s 343ms/step - loss: 0.9450 - dense_3_loss: 0.5415 - dense_4_loss: 0.2409 - dense_5_loss: 0.1625 - dense_3_acc: 0.8392 - dense_4_acc: 0.9253 - dense_5_acc: 0.9472 - val_loss: 0.9395 - val_dense_3_loss: 0.5999 - val_dense_4_loss: 0.2113 - val_dense_5_loss: 0.1283 - val_dense_3_acc: 0.8603 - val_dense_4_acc: 0.9400 - val_dense_5_acc: 0.9622
# Epoch 30/30
# 180/180 [==============================] - 65s 363ms/step - loss: 0.9423 - dense_3_loss: 0.5335 - dense_4_loss: 0.2429 - dense_5_loss: 0.1659 - dense_3_acc: 0.8424 - dense_4_acc: 0.9235 - dense_5_acc: 0.9469 - val_loss: 1.3508 - val_dense_3_loss: 0.7789 - val_dense_4_loss: 0.3538 - val_dense_5_loss: 0.2181 - val_dense_3_acc: 0.8511 - val_dense_4_acc: 0.9358 - val_dense_5_acc: 0.9594
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 41s 225ms/step - loss: 1.4877 - dense_3_loss: 0.8991 - dense_4_loss: 0.3413 - dense_5_loss: 0.2473 - dense_3_acc: 0.7549 - dense_4_acc: 0.8941 - dense_5_acc: 0.9219 - val_loss: 0.7169 - val_dense_3_loss: 0.4254 - val_dense_4_loss: 0.1437 - val_dense_5_loss: 0.1478 - val_dense_3_acc: 0.8753 - val_dense_4_acc: 0.9549 - val_dense_5_acc: 0.9525
# Epoch 2/30
# 180/180 [==============================] - 47s 264ms/step - loss: 1.2332 - dense_3_loss: 0.7286 - dense_4_loss: 0.2895 - dense_5_loss: 0.2151 - dense_3_acc: 0.7948 - dense_4_acc: 0.9107 - dense_5_acc: 0.9314 - val_loss: 0.6384 - val_dense_3_loss: 0.3971 - val_dense_4_loss: 0.1395 - val_dense_5_loss: 0.1018 - val_dense_3_acc: 0.8823 - val_dense_4_acc: 0.9592 - val_dense_5_acc: 0.9699
# Epoch 3/30
# 180/180 [==============================] - 55s 308ms/step - loss: 1.4080 - dense_3_loss: 0.8282 - dense_4_loss: 0.3345 - dense_5_loss: 0.2454 - dense_3_acc: 0.7728 - dense_4_acc: 0.8963 - dense_5_acc: 0.9212 - val_loss: 0.6464 - val_dense_3_loss: 0.4248 - val_dense_4_loss: 0.1177 - val_dense_5_loss: 0.1038 - val_dense_3_acc: 0.8810 - val_dense_4_acc: 0.9644 - val_dense_5_acc: 0.9674
# Epoch 4/30
# 180/180 [==============================] - 61s 338ms/step - loss: 1.3761 - dense_3_loss: 0.8089 - dense_4_loss: 0.3260 - dense_5_loss: 0.2412 - dense_3_acc: 0.7721 - dense_4_acc: 0.8988 - dense_5_acc: 0.9214 - val_loss: 0.6588 - val_dense_3_loss: 0.4226 - val_dense_4_loss: 0.1252 - val_dense_5_loss: 0.1110 - val_dense_3_acc: 0.8730 - val_dense_4_acc: 0.9642 - val_dense_5_acc: 0.9699
# Epoch 5/30
# 180/180 [==============================] - 64s 358ms/step - loss: 1.1175 - dense_3_loss: 0.6446 - dense_4_loss: 0.2759 - dense_5_loss: 0.1971 - dense_3_acc: 0.8166 - dense_4_acc: 0.9154 - dense_5_acc: 0.9360 - val_loss: 0.6739 - val_dense_3_loss: 0.4249 - val_dense_4_loss: 0.1389 - val_dense_5_loss: 0.1101 - val_dense_3_acc: 0.8743 - val_dense_4_acc: 0.9634 - val_dense_5_acc: 0.9649
# Epoch 6/30
# 180/180 [==============================] - 64s 353ms/step - loss: 1.0459 - dense_3_loss: 0.6016 - dense_4_loss: 0.2594 - dense_5_loss: 0.1848 - dense_3_acc: 0.8288 - dense_4_acc: 0.9190 - dense_5_acc: 0.9406 - val_loss: 0.9282 - val_dense_3_loss: 0.5658 - val_dense_4_loss: 0.2003 - val_dense_5_loss: 0.1621 - val_dense_3_acc: 0.8663 - val_dense_4_acc: 0.9547 - val_dense_5_acc: 0.9599
# Epoch 7/30
# 180/180 [==============================] - 62s 343ms/step - loss: 0.9770 - dense_3_loss: 0.5595 - dense_4_loss: 0.2405 - dense_5_loss: 0.1770 - dense_3_acc: 0.8368 - dense_4_acc: 0.9257 - dense_5_acc: 0.9426 - val_loss: 0.5977 - val_dense_3_loss: 0.3803 - val_dense_4_loss: 0.1177 - val_dense_5_loss: 0.0997 - val_dense_3_acc: 0.8917 - val_dense_4_acc: 0.9671 - val_dense_5_acc: 0.9701
# Epoch 8/30
# 180/180 [==============================] - 62s 347ms/step - loss: 0.9640 - dense_3_loss: 0.5504 - dense_4_loss: 0.2417 - dense_5_loss: 0.1719 - dense_3_acc: 0.8422 - dense_4_acc: 0.9257 - dense_5_acc: 0.9453 - val_loss: 0.6067 - val_dense_3_loss: 0.3862 - val_dense_4_loss: 0.1149 - val_dense_5_loss: 0.1055 - val_dense_3_acc: 0.8857 - val_dense_4_acc: 0.9666 - val_dense_5_acc: 0.9691
# Epoch 9/30
# 180/180 [==============================] - 62s 347ms/step - loss: 1.0584 - dense_3_loss: 0.6135 - dense_4_loss: 0.2609 - dense_5_loss: 0.1840 - dense_3_acc: 0.8268 - dense_4_acc: 0.9181 - dense_5_acc: 0.9431 - val_loss: 0.6559 - val_dense_3_loss: 0.4184 - val_dense_4_loss: 0.1314 - val_dense_5_loss: 0.1061 - val_dense_3_acc: 0.8855 - val_dense_4_acc: 0.9619 - val_dense_5_acc: 0.9711
# Epoch 10/30
# 180/180 [==============================] - 63s 349ms/step - loss: 1.1241 - dense_3_loss: 0.6492 - dense_4_loss: 0.2820 - dense_5_loss: 0.1928 - dense_3_acc: 0.8142 - dense_4_acc: 0.9126 - dense_5_acc: 0.9381 - val_loss: 0.6256 - val_dense_3_loss: 0.3903 - val_dense_4_loss: 0.1276 - val_dense_5_loss: 0.1077 - val_dense_3_acc: 0.8892 - val_dense_4_acc: 0.9599 - val_dense_5_acc: 0.9666
# Epoch 11/30
# 180/180 [==============================] - 66s 369ms/step - loss: 0.9166 - dense_3_loss: 0.5223 - dense_4_loss: 0.2309 - dense_5_loss: 0.1634 - dense_3_acc: 0.8471 - dense_4_acc: 0.9281 - dense_5_acc: 0.9475 - val_loss: 0.6728 - val_dense_3_loss: 0.4310 - val_dense_4_loss: 0.1249 - val_dense_5_loss: 0.1170 - val_dense_3_acc: 0.8765 - val_dense_4_acc: 0.9637 - val_dense_5_acc: 0.9664
# Epoch 12/30
# 180/180 [==============================] - 67s 370ms/step - loss: 1.0575 - dense_3_loss: 0.5994 - dense_4_loss: 0.2668 - dense_5_loss: 0.1913 - dense_3_acc: 0.8295 - dense_4_acc: 0.9166 - dense_5_acc: 0.9386 - val_loss: 0.5979 - val_dense_3_loss: 0.3697 - val_dense_4_loss: 0.1250 - val_dense_5_loss: 0.1032 - val_dense_3_acc: 0.8922 - val_dense_4_acc: 0.9681 - val_dense_5_acc: 0.9694
# Epoch 13/30
# 180/180 [==============================] - 66s 369ms/step - loss: 0.9533 - dense_3_loss: 0.5265 - dense_4_loss: 0.2513 - dense_5_loss: 0.1755 - dense_3_acc: 0.8490 - dense_4_acc: 0.9243 - dense_5_acc: 0.9431 - val_loss: 0.5410 - val_dense_3_loss: 0.3345 - val_dense_4_loss: 0.1092 - val_dense_5_loss: 0.0973 - val_dense_3_acc: 0.8997 - val_dense_4_acc: 0.9711 - val_dense_5_acc: 0.9724
# Epoch 14/30
# 180/180 [==============================] - 67s 371ms/step - loss: 0.9077 - dense_3_loss: 0.5032 - dense_4_loss: 0.2352 - dense_5_loss: 0.1693 - dense_3_acc: 0.8540 - dense_4_acc: 0.9292 - dense_5_acc: 0.9464 - val_loss: 0.7215 - val_dense_3_loss: 0.4591 - val_dense_4_loss: 0.1469 - val_dense_5_loss: 0.1155 - val_dense_3_acc: 0.8780 - val_dense_4_acc: 0.9562 - val_dense_5_acc: 0.9669
# Epoch 15/30
# 180/180 [==============================] - 67s 370ms/step - loss: 1.2123 - dense_3_loss: 0.7053 - dense_4_loss: 0.2982 - dense_5_loss: 0.2088 - dense_3_acc: 0.8093 - dense_4_acc: 0.9114 - dense_5_acc: 0.9366 - val_loss: 0.7350 - val_dense_3_loss: 0.4610 - val_dense_4_loss: 0.1507 - val_dense_5_loss: 0.1232 - val_dense_3_acc: 0.8753 - val_dense_4_acc: 0.9607 - val_dense_5_acc: 0.9649
# Epoch 16/30
# 180/180 [==============================] - 67s 372ms/step - loss: 1.0089 - dense_3_loss: 0.5758 - dense_4_loss: 0.2573 - dense_5_loss: 0.1758 - dense_3_acc: 0.8368 - dense_4_acc: 0.9236 - dense_5_acc: 0.9471 - val_loss: 0.6072 - val_dense_3_loss: 0.3874 - val_dense_4_loss: 0.1194 - val_dense_5_loss: 0.1004 - val_dense_3_acc: 0.8972 - val_dense_4_acc: 0.9696 - val_dense_5_acc: 0.9724
# Epoch 17/30
# 180/180 [==============================] - 69s 385ms/step - loss: 0.8524 - dense_3_loss: 0.4796 - dense_4_loss: 0.2211 - dense_5_loss: 0.1517 - dense_3_acc: 0.8618 - dense_4_acc: 0.9342 - dense_5_acc: 0.9527 - val_loss: 0.6032 - val_dense_3_loss: 0.3646 - val_dense_4_loss: 0.1248 - val_dense_5_loss: 0.1138 - val_dense_3_acc: 0.9032 - val_dense_4_acc: 0.9674 - val_dense_5_acc: 0.9669
# Epoch 18/30
# 180/180 [==============================] - 71s 392ms/step - loss: 0.9886 - dense_3_loss: 0.5620 - dense_4_loss: 0.2495 - dense_5_loss: 0.1771 - dense_3_acc: 0.8424 - dense_4_acc: 0.9262 - dense_5_acc: 0.9442 - val_loss: 0.5791 - val_dense_3_loss: 0.3587 - val_dense_4_loss: 0.1152 - val_dense_5_loss: 0.1052 - val_dense_3_acc: 0.9034 - val_dense_4_acc: 0.9696 - val_dense_5_acc: 0.9689
# Epoch 19/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.8221 - dense_3_loss: 0.4555 - dense_4_loss: 0.2150 - dense_5_loss: 0.1516 - dense_3_acc: 0.8683 - dense_4_acc: 0.9342 - dense_5_acc: 0.9530 - val_loss: 0.5588 - val_dense_3_loss: 0.3428 - val_dense_4_loss: 0.1123 - val_dense_5_loss: 0.1037 - val_dense_3_acc: 0.9017 - val_dense_4_acc: 0.9729 - val_dense_5_acc: 0.9696
# Epoch 20/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.7279 - dense_3_loss: 0.4048 - dense_4_loss: 0.1910 - dense_5_loss: 0.1321 - dense_3_acc: 0.8809 - dense_4_acc: 0.9403 - dense_5_acc: 0.9575 - val_loss: 0.5370 - val_dense_3_loss: 0.3265 - val_dense_4_loss: 0.1177 - val_dense_5_loss: 0.0928 - val_dense_3_acc: 0.9106 - val_dense_4_acc: 0.9679 - val_dense_5_acc: 0.9741
# Epoch 21/30
# 180/180 [==============================] - 71s 394ms/step - loss: 0.7033 - dense_3_loss: 0.3850 - dense_4_loss: 0.1893 - dense_5_loss: 0.1290 - dense_3_acc: 0.8848 - dense_4_acc: 0.9415 - dense_5_acc: 0.9591 - val_loss: 0.5359 - val_dense_3_loss: 0.3272 - val_dense_4_loss: 0.1131 - val_dense_5_loss: 0.0956 - val_dense_3_acc: 0.9089 - val_dense_4_acc: 0.9716 - val_dense_5_acc: 0.9729
# Epoch 22/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.7401 - dense_3_loss: 0.4135 - dense_4_loss: 0.1923 - dense_5_loss: 0.1343 - dense_3_acc: 0.8785 - dense_4_acc: 0.9408 - dense_5_acc: 0.9583 - val_loss: 0.6003 - val_dense_3_loss: 0.3714 - val_dense_4_loss: 0.1290 - val_dense_5_loss: 0.0999 - val_dense_3_acc: 0.9007 - val_dense_4_acc: 0.9644 - val_dense_5_acc: 0.9674
# Epoch 23/30
# 180/180 [==============================] - 71s 394ms/step - loss: 0.7514 - dense_3_loss: 0.4139 - dense_4_loss: 0.2002 - dense_5_loss: 0.1373 - dense_3_acc: 0.8768 - dense_4_acc: 0.9385 - dense_5_acc: 0.9569 - val_loss: 0.6011 - val_dense_3_loss: 0.3719 - val_dense_4_loss: 0.1303 - val_dense_5_loss: 0.0989 - val_dense_3_acc: 0.8992 - val_dense_4_acc: 0.9654 - val_dense_5_acc: 0.9714
# Epoch 24/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.6760 - dense_3_loss: 0.3674 - dense_4_loss: 0.1856 - dense_5_loss: 0.1231 - dense_3_acc: 0.8888 - dense_4_acc: 0.9437 - dense_5_acc: 0.9606 - val_loss: 0.5582 - val_dense_3_loss: 0.3315 - val_dense_4_loss: 0.1331 - val_dense_5_loss: 0.0936 - val_dense_3_acc: 0.9119 - val_dense_4_acc: 0.9664 - val_dense_5_acc: 0.9746
# Epoch 25/30
# 180/180 [==============================] - 71s 392ms/step - loss: 0.6183 - dense_3_loss: 0.3355 - dense_4_loss: 0.1667 - dense_5_loss: 0.1161 - dense_3_acc: 0.8975 - dense_4_acc: 0.9489 - dense_5_acc: 0.9628 - val_loss: 0.5387 - val_dense_3_loss: 0.3216 - val_dense_4_loss: 0.1255 - val_dense_5_loss: 0.0916 - val_dense_3_acc: 0.9139 - val_dense_4_acc: 0.9671 - val_dense_5_acc: 0.9736
# Epoch 26/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.5864 - dense_3_loss: 0.3172 - dense_4_loss: 0.1612 - dense_5_loss: 0.1080 - dense_3_acc: 0.9029 - dense_4_acc: 0.9520 - dense_5_acc: 0.9660 - val_loss: 0.5413 - val_dense_3_loss: 0.3388 - val_dense_4_loss: 0.1171 - val_dense_5_loss: 0.0854 - val_dense_3_acc: 0.9191 - val_dense_4_acc: 0.9744 - val_dense_5_acc: 0.9771
# Epoch 27/30
# 180/180 [==============================] - 70s 388ms/step - loss: 0.5791 - dense_3_loss: 0.3075 - dense_4_loss: 0.1629 - dense_5_loss: 0.1087 - dense_3_acc: 0.9067 - dense_4_acc: 0.9507 - dense_5_acc: 0.9661 - val_loss: 1.3707 - val_dense_3_loss: 0.4536 - val_dense_4_loss: 0.7813 - val_dense_5_loss: 0.1358 - val_dense_3_acc: 0.8902 - val_dense_4_acc: 0.8108 - val_dense_5_acc: 0.9567
# Epoch 28/30
# 180/180 [==============================] - 69s 385ms/step - loss: 0.5708 - dense_3_loss: 0.3034 - dense_4_loss: 0.1552 - dense_5_loss: 0.1123 - dense_3_acc: 0.9086 - dense_4_acc: 0.9533 - dense_5_acc: 0.9655 - val_loss: 0.5763 - val_dense_3_loss: 0.3381 - val_dense_4_loss: 0.1353 - val_dense_5_loss: 0.1030 - val_dense_3_acc: 0.9136 - val_dense_4_acc: 0.9704 - val_dense_5_acc: 0.9744
# Epoch 29/30
# 180/180 [==============================] - 64s 358ms/step - loss: 0.5420 - dense_3_loss: 0.2869 - dense_4_loss: 0.1500 - dense_5_loss: 0.1051 - dense_3_acc: 0.9102 - dense_4_acc: 0.9551 - dense_5_acc: 0.9672 - val_loss: 0.5276 - val_dense_3_loss: 0.3221 - val_dense_4_loss: 0.1098 - val_dense_5_loss: 0.0957 - val_dense_3_acc: 0.9124 - val_dense_4_acc: 0.9726 - val_dense_5_acc: 0.9756
# Epoch 30/30
# 180/180 [==============================] - 71s 393ms/step - loss: 0.5387 - dense_3_loss: 0.2860 - dense_4_loss: 0.1520 - dense_5_loss: 0.1008 - dense_3_acc: 0.9107 - dense_4_acc: 0.9532 - dense_5_acc: 0.9676 - val_loss: 0.5093 - val_dense_3_loss: 0.3132 - val_dense_4_loss: 0.1153 - val_dense_5_loss: 0.0807 - val_dense_3_acc: 0.9176 - val_dense_4_acc: 0.9696 - val_dense_5_acc: 0.9803
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 41s 225ms/step - loss: 0.8856 - dense_3_loss: 0.5179 - dense_4_loss: 0.2129 - dense_5_loss: 0.1547 - dense_3_acc: 0.8582 - dense_4_acc: 0.9380 - dense_5_acc: 0.9530 - val_loss: 0.4601 - val_dense_3_loss: 0.2830 - val_dense_4_loss: 0.0951 - val_dense_5_loss: 0.0820 - val_dense_3_acc: 0.9193 - val_dense_4_acc: 0.9781 - val_dense_5_acc: 0.9759
# Epoch 2/30
# 180/180 [==============================] - 48s 267ms/step - loss: 0.7774 - dense_3_loss: 0.4420 - dense_4_loss: 0.1957 - dense_5_loss: 0.1397 - dense_3_acc: 0.8743 - dense_4_acc: 0.9418 - dense_5_acc: 0.9570 - val_loss: 0.8205 - val_dense_3_loss: 0.3398 - val_dense_4_loss: 0.3667 - val_dense_5_loss: 0.1140 - val_dense_3_acc: 0.9081 - val_dense_4_acc: 0.8847 - val_dense_5_acc: 0.9669
# Epoch 3/30
# 180/180 [==============================] - 64s 355ms/step - loss: 0.7170 - dense_3_loss: 0.3993 - dense_4_loss: 0.1866 - dense_5_loss: 0.1311 - dense_3_acc: 0.8847 - dense_4_acc: 0.9444 - dense_5_acc: 0.9595 - val_loss: 0.4807 - val_dense_3_loss: 0.2634 - val_dense_4_loss: 0.1295 - val_dense_5_loss: 0.0878 - val_dense_3_acc: 0.9263 - val_dense_4_acc: 0.9651 - val_dense_5_acc: 0.9749
# Epoch 4/30
# 180/180 [==============================] - 64s 353ms/step - loss: 0.6706 - dense_3_loss: 0.3736 - dense_4_loss: 0.1736 - dense_5_loss: 0.1233 - dense_3_acc: 0.8913 - dense_4_acc: 0.9490 - dense_5_acc: 0.9622 - val_loss: 0.4205 - val_dense_3_loss: 0.2478 - val_dense_4_loss: 0.0977 - val_dense_5_loss: 0.0749 - val_dense_3_acc: 0.9278 - val_dense_4_acc: 0.9739 - val_dense_5_acc: 0.9773
# Epoch 5/30
# 180/180 [==============================] - 64s 358ms/step - loss: 0.6353 - dense_3_loss: 0.3453 - dense_4_loss: 0.1715 - dense_5_loss: 0.1185 - dense_3_acc: 0.8970 - dense_4_acc: 0.9491 - dense_5_acc: 0.9630 - val_loss: 0.4330 - val_dense_3_loss: 0.2601 - val_dense_4_loss: 0.0884 - val_dense_5_loss: 0.0844 - val_dense_3_acc: 0.9286 - val_dense_4_acc: 0.9768 - val_dense_5_acc: 0.9761
# Epoch 6/30
# 180/180 [==============================] - 65s 362ms/step - loss: 0.6105 - dense_3_loss: 0.3318 - dense_4_loss: 0.1662 - dense_5_loss: 0.1126 - dense_3_acc: 0.8997 - dense_4_acc: 0.9510 - dense_5_acc: 0.9652 - val_loss: 0.4533 - val_dense_3_loss: 0.2742 - val_dense_4_loss: 0.0906 - val_dense_5_loss: 0.0884 - val_dense_3_acc: 0.9258 - val_dense_4_acc: 0.9783 - val_dense_5_acc: 0.9754
# Epoch 7/30
# 180/180 [==============================] - 66s 365ms/step - loss: 0.5896 - dense_3_loss: 0.3189 - dense_4_loss: 0.1602 - dense_5_loss: 0.1104 - dense_3_acc: 0.9041 - dense_4_acc: 0.9518 - dense_5_acc: 0.9652 - val_loss: 0.4450 - val_dense_3_loss: 0.2608 - val_dense_4_loss: 0.0949 - val_dense_5_loss: 0.0893 - val_dense_3_acc: 0.9276 - val_dense_4_acc: 0.9766 - val_dense_5_acc: 0.9751
# Epoch 8/30
# 180/180 [==============================] - 66s 365ms/step - loss: 0.5638 - dense_3_loss: 0.3020 - dense_4_loss: 0.1545 - dense_5_loss: 0.1073 - dense_3_acc: 0.9091 - dense_4_acc: 0.9539 - dense_5_acc: 0.9663 - val_loss: 0.4449 - val_dense_3_loss: 0.2723 - val_dense_4_loss: 0.0880 - val_dense_5_loss: 0.0846 - val_dense_3_acc: 0.9313 - val_dense_4_acc: 0.9781 - val_dense_5_acc: 0.9776
# Epoch 9/30
# 180/180 [==============================] - 66s 365ms/step - loss: 0.5586 - dense_3_loss: 0.2991 - dense_4_loss: 0.1523 - dense_5_loss: 0.1072 - dense_3_acc: 0.9097 - dense_4_acc: 0.9544 - dense_5_acc: 0.9670 - val_loss: 0.4033 - val_dense_3_loss: 0.2519 - val_dense_4_loss: 0.0740 - val_dense_5_loss: 0.0774 - val_dense_3_acc: 0.9320 - val_dense_4_acc: 0.9813 - val_dense_5_acc: 0.9768
# Epoch 10/30
# 180/180 [==============================] - 66s 365ms/step - loss: 0.5492 - dense_3_loss: 0.2896 - dense_4_loss: 0.1534 - dense_5_loss: 0.1062 - dense_3_acc: 0.9105 - dense_4_acc: 0.9543 - dense_5_acc: 0.9677 - val_loss: 0.4078 - val_dense_3_loss: 0.2511 - val_dense_4_loss: 0.0805 - val_dense_5_loss: 0.0762 - val_dense_3_acc: 0.9310 - val_dense_4_acc: 0.9796 - val_dense_5_acc: 0.9759
# Epoch 11/30
# 180/180 [==============================] - 63s 350ms/step - loss: 0.5247 - dense_3_loss: 0.2815 - dense_4_loss: 0.1412 - dense_5_loss: 0.1020 - dense_3_acc: 0.9150 - dense_4_acc: 0.9577 - dense_5_acc: 0.9676 - val_loss: 0.4069 - val_dense_3_loss: 0.2430 - val_dense_4_loss: 0.0813 - val_dense_5_loss: 0.0825 - val_dense_3_acc: 0.9365 - val_dense_4_acc: 0.9813 - val_dense_5_acc: 0.9761
# Epoch 12/30
# 180/180 [==============================] - 63s 352ms/step - loss: 0.5122 - dense_3_loss: 0.2721 - dense_4_loss: 0.1427 - dense_5_loss: 0.0974 - dense_3_acc: 0.9151 - dense_4_acc: 0.9579 - dense_5_acc: 0.9693 - val_loss: 0.4118 - val_dense_3_loss: 0.2546 - val_dense_4_loss: 0.0791 - val_dense_5_loss: 0.0781 - val_dense_3_acc: 0.9330 - val_dense_4_acc: 0.9813 - val_dense_5_acc: 0.9786
# Epoch 13/30
# 180/180 [==============================] - 64s 358ms/step - loss: 0.5091 - dense_3_loss: 0.2627 - dense_4_loss: 0.1468 - dense_5_loss: 0.0996 - dense_3_acc: 0.9193 - dense_4_acc: 0.9553 - dense_5_acc: 0.9692 - val_loss: 0.4433 - val_dense_3_loss: 0.2678 - val_dense_4_loss: 0.0911 - val_dense_5_loss: 0.0844 - val_dense_3_acc: 0.9283 - val_dense_4_acc: 0.9761 - val_dense_5_acc: 0.9764
# Epoch 14/30
# 180/180 [==============================] - 65s 359ms/step - loss: 0.4993 - dense_3_loss: 0.2600 - dense_4_loss: 0.1425 - dense_5_loss: 0.0968 - dense_3_acc: 0.9200 - dense_4_acc: 0.9571 - dense_5_acc: 0.9696 - val_loss: 0.4147 - val_dense_3_loss: 0.2563 - val_dense_4_loss: 0.0858 - val_dense_5_loss: 0.0726 - val_dense_3_acc: 0.9288 - val_dense_4_acc: 0.9781 - val_dense_5_acc: 0.9778
# Epoch 15/30
# 180/180 [==============================] - 62s 343ms/step - loss: 0.4883 - dense_3_loss: 0.2582 - dense_4_loss: 0.1349 - dense_5_loss: 0.0952 - dense_3_acc: 0.9206 - dense_4_acc: 0.9600 - dense_5_acc: 0.9697 - val_loss: 0.4446 - val_dense_3_loss: 0.2613 - val_dense_4_loss: 0.1065 - val_dense_5_loss: 0.0767 - val_dense_3_acc: 0.9308 - val_dense_4_acc: 0.9746 - val_dense_5_acc: 0.9788
# Epoch 16/30
# 180/180 [==============================] - 62s 343ms/step - loss: 0.4693 - dense_3_loss: 0.2392 - dense_4_loss: 0.1387 - dense_5_loss: 0.0913 - dense_3_acc: 0.9256 - dense_4_acc: 0.9591 - dense_5_acc: 0.9709 - val_loss: 0.4238 - val_dense_3_loss: 0.2535 - val_dense_4_loss: 0.0926 - val_dense_5_loss: 0.0777 - val_dense_3_acc: 0.9315 - val_dense_4_acc: 0.9766 - val_dense_5_acc: 0.9786
# Epoch 17/30
# 180/180 [==============================] - 64s 356ms/step - loss: 0.4644 - dense_3_loss: 0.2418 - dense_4_loss: 0.1315 - dense_5_loss: 0.0911 - dense_3_acc: 0.9251 - dense_4_acc: 0.9609 - dense_5_acc: 0.9711 - val_loss: 0.4469 - val_dense_3_loss: 0.2657 - val_dense_4_loss: 0.1035 - val_dense_5_loss: 0.0777 - val_dense_3_acc: 0.9335 - val_dense_4_acc: 0.9721 - val_dense_5_acc: 0.9786
# Epoch 18/30
# 180/180 [==============================] - 63s 351ms/step - loss: 0.4472 - dense_3_loss: 0.2311 - dense_4_loss: 0.1296 - dense_5_loss: 0.0865 - dense_3_acc: 0.9290 - dense_4_acc: 0.9612 - dense_5_acc: 0.9729 - val_loss: 0.5765 - val_dense_3_loss: 0.2676 - val_dense_4_loss: 0.2245 - val_dense_5_loss: 0.0844 - val_dense_3_acc: 0.9288 - val_dense_4_acc: 0.9375 - val_dense_5_acc: 0.9768
# Epoch 19/30
# 180/180 [==============================] - 61s 336ms/step - loss: 0.4424 - dense_3_loss: 0.2267 - dense_4_loss: 0.1275 - dense_5_loss: 0.0882 - dense_3_acc: 0.9295 - dense_4_acc: 0.9613 - dense_5_acc: 0.9721 - val_loss: 0.4322 - val_dense_3_loss: 0.2585 - val_dense_4_loss: 0.0941 - val_dense_5_loss: 0.0797 - val_dense_3_acc: 0.9335 - val_dense_4_acc: 0.9786 - val_dense_5_acc: 0.9786
# Epoch 20/30
# 180/180 [==============================] - 63s 350ms/step - loss: 0.4399 - dense_3_loss: 0.2271 - dense_4_loss: 0.1269 - dense_5_loss: 0.0859 - dense_3_acc: 0.9293 - dense_4_acc: 0.9615 - dense_5_acc: 0.9724 - val_loss: 0.4573 - val_dense_3_loss: 0.2649 - val_dense_4_loss: 0.1065 - val_dense_5_loss: 0.0858 - val_dense_3_acc: 0.9268 - val_dense_4_acc: 0.9731 - val_dense_5_acc: 0.9749
# Epoch 21/30
# 180/180 [==============================] - 64s 354ms/step - loss: 0.4317 - dense_3_loss: 0.2173 - dense_4_loss: 0.1301 - dense_5_loss: 0.0844 - dense_3_acc: 0.9331 - dense_4_acc: 0.9609 - dense_5_acc: 0.9737 - val_loss: 0.4243 - val_dense_3_loss: 0.2555 - val_dense_4_loss: 0.0848 - val_dense_5_loss: 0.0841 - val_dense_3_acc: 0.9323 - val_dense_4_acc: 0.9796 - val_dense_5_acc: 0.9761
# Epoch 22/30
# 180/180 [==============================] - 65s 360ms/step - loss: 0.4311 - dense_3_loss: 0.2169 - dense_4_loss: 0.1314 - dense_5_loss: 0.0828 - dense_3_acc: 0.9335 - dense_4_acc: 0.9611 - dense_5_acc: 0.9742 - val_loss: 0.4581 - val_dense_3_loss: 0.2611 - val_dense_4_loss: 0.1151 - val_dense_5_loss: 0.0819 - val_dense_3_acc: 0.9335 - val_dense_4_acc: 0.9736 - val_dense_5_acc: 0.9754
# Epoch 23/30
# 180/180 [==============================] - 67s 372ms/step - loss: 0.4107 - dense_3_loss: 0.2092 - dense_4_loss: 0.1220 - dense_5_loss: 0.0795 - dense_3_acc: 0.9349 - dense_4_acc: 0.9632 - dense_5_acc: 0.9746 - val_loss: 0.9311 - val_dense_3_loss: 0.3115 - val_dense_4_loss: 0.5026 - val_dense_5_loss: 0.1169 - val_dense_3_acc: 0.9203 - val_dense_4_acc: 0.8611 - val_dense_5_acc: 0.9659
# Epoch 24/30
# 180/180 [==============================] - 63s 348ms/step - loss: 0.4091 - dense_3_loss: 0.2073 - dense_4_loss: 0.1187 - dense_5_loss: 0.0832 - dense_3_acc: 0.9358 - dense_4_acc: 0.9639 - dense_5_acc: 0.9738 - val_loss: 0.4600 - val_dense_3_loss: 0.2767 - val_dense_4_loss: 0.0992 - val_dense_5_loss: 0.0841 - val_dense_3_acc: 0.9291 - val_dense_4_acc: 0.9746 - val_dense_5_acc: 0.9778
# Epoch 25/30
# 180/180 [==============================] - 66s 367ms/step - loss: 0.4117 - dense_3_loss: 0.2084 - dense_4_loss: 0.1223 - dense_5_loss: 0.0810 - dense_3_acc: 0.9348 - dense_4_acc: 0.9636 - dense_5_acc: 0.9747 - val_loss: 0.4569 - val_dense_3_loss: 0.2732 - val_dense_4_loss: 0.1015 - val_dense_5_loss: 0.0822 - val_dense_3_acc: 0.9348 - val_dense_4_acc: 0.9759 - val_dense_5_acc: 0.9786
# Epoch 26/30
# 180/180 [==============================] - 66s 367ms/step - loss: 0.3987 - dense_3_loss: 0.2006 - dense_4_loss: 0.1189 - dense_5_loss: 0.0792 - dense_3_acc: 0.9359 - dense_4_acc: 0.9647 - dense_5_acc: 0.9747 - val_loss: 0.4447 - val_dense_3_loss: 0.2689 - val_dense_4_loss: 0.0885 - val_dense_5_loss: 0.0873 - val_dense_3_acc: 0.9308 - val_dense_4_acc: 0.9781 - val_dense_5_acc: 0.9768
# Epoch 27/30
# 180/180 [==============================] - 71s 393ms/step - loss: 0.3923 - dense_3_loss: 0.1941 - dense_4_loss: 0.1225 - dense_5_loss: 0.0757 - dense_3_acc: 0.9392 - dense_4_acc: 0.9632 - dense_5_acc: 0.9767 - val_loss: 0.4395 - val_dense_3_loss: 0.2684 - val_dense_4_loss: 0.0879 - val_dense_5_loss: 0.0832 - val_dense_3_acc: 0.9320 - val_dense_4_acc: 0.9786 - val_dense_5_acc: 0.9788
# Epoch 28/30
# 180/180 [==============================] - 69s 383ms/step - loss: 0.3948 - dense_3_loss: 0.1921 - dense_4_loss: 0.1228 - dense_5_loss: 0.0799 - dense_3_acc: 0.9410 - dense_4_acc: 0.9622 - dense_5_acc: 0.9750 - val_loss: 0.4135 - val_dense_3_loss: 0.2549 - val_dense_4_loss: 0.0806 - val_dense_5_loss: 0.0781 - val_dense_3_acc: 0.9353 - val_dense_4_acc: 0.9798 - val_dense_5_acc: 0.9788
# Epoch 29/30
# 180/180 [==============================] - 68s 377ms/step - loss: 0.3890 - dense_3_loss: 0.1952 - dense_4_loss: 0.1199 - dense_5_loss: 0.0740 - dense_3_acc: 0.9400 - dense_4_acc: 0.9637 - dense_5_acc: 0.9766 - val_loss: 0.3882 - val_dense_3_loss: 0.2391 - val_dense_4_loss: 0.0792 - val_dense_5_loss: 0.0700 - val_dense_3_acc: 0.9360 - val_dense_4_acc: 0.9803 - val_dense_5_acc: 0.9798
# Epoch 30/30
# 180/180 [==============================] - 71s 395ms/step - loss: 0.3830 - dense_3_loss: 0.1865 - dense_4_loss: 0.1212 - dense_5_loss: 0.0752 - dense_3_acc: 0.9416 - dense_4_acc: 0.9630 - dense_5_acc: 0.9763 - val_loss: 0.4321 - val_dense_3_loss: 0.2499 - val_dense_4_loss: 0.1016 - val_dense_5_loss: 0.0806 - val_dense_3_acc: 0.9358 - val_dense_4_acc: 0.9778 - val_dense_5_acc: 0.9773
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 41s 225ms/step - loss: 0.7494 - dense_3_loss: 0.4293 - dense_4_loss: 0.1875 - dense_5_loss: 0.1326 - dense_3_acc: 0.8818 - dense_4_acc: 0.9467 - dense_5_acc: 0.9612 - val_loss: 0.4012 - val_dense_3_loss: 0.2477 - val_dense_4_loss: 0.0893 - val_dense_5_loss: 0.0642 - val_dense_3_acc: 0.9310 - val_dense_4_acc: 0.9776 - val_dense_5_acc: 0.9821
# Epoch 2/30
# 180/180 [==============================] - 52s 290ms/step - loss: 0.6240 - dense_3_loss: 0.3486 - dense_4_loss: 0.1595 - dense_5_loss: 0.1159 - dense_3_acc: 0.8993 - dense_4_acc: 0.9542 - dense_5_acc: 0.9653 - val_loss: 0.3719 - val_dense_3_loss: 0.2257 - val_dense_4_loss: 0.0815 - val_dense_5_loss: 0.0647 - val_dense_3_acc: 0.9368 - val_dense_4_acc: 0.9808 - val_dense_5_acc: 0.9801
# Epoch 3/30
# 180/180 [==============================] - 63s 350ms/step - loss: 0.5733 - dense_3_loss: 0.3160 - dense_4_loss: 0.1495 - dense_5_loss: 0.1078 - dense_3_acc: 0.9088 - dense_4_acc: 0.9564 - dense_5_acc: 0.9668 - val_loss: 0.3650 - val_dense_3_loss: 0.2266 - val_dense_4_loss: 0.0836 - val_dense_5_loss: 0.0548 - val_dense_3_acc: 0.9363 - val_dense_4_acc: 0.9806 - val_dense_5_acc: 0.9836
# Epoch 4/30
# 180/180 [==============================] - 68s 379ms/step - loss: 0.5383 - dense_3_loss: 0.2935 - dense_4_loss: 0.1456 - dense_5_loss: 0.0992 - dense_3_acc: 0.9130 - dense_4_acc: 0.9575 - dense_5_acc: 0.9694 - val_loss: 0.3639 - val_dense_3_loss: 0.2315 - val_dense_4_loss: 0.0779 - val_dense_5_loss: 0.0544 - val_dense_3_acc: 0.9368 - val_dense_4_acc: 0.9836 - val_dense_5_acc: 0.9838
# Epoch 5/30
# 180/180 [==============================] - 69s 383ms/step - loss: 0.5235 - dense_3_loss: 0.2819 - dense_4_loss: 0.1398 - dense_5_loss: 0.1018 - dense_3_acc: 0.9160 - dense_4_acc: 0.9587 - dense_5_acc: 0.9690 - val_loss: 0.3720 - val_dense_3_loss: 0.2382 - val_dense_4_loss: 0.0774 - val_dense_5_loss: 0.0564 - val_dense_3_acc: 0.9360 - val_dense_4_acc: 0.9801 - val_dense_5_acc: 0.9848
# Epoch 6/30
# 180/180 [==============================] - 66s 369ms/step - loss: 0.4891 - dense_3_loss: 0.2537 - dense_4_loss: 0.1393 - dense_5_loss: 0.0960 - dense_3_acc: 0.9233 - dense_4_acc: 0.9588 - dense_5_acc: 0.9696 - val_loss: 0.3788 - val_dense_3_loss: 0.2291 - val_dense_4_loss: 0.0879 - val_dense_5_loss: 0.0618 - val_dense_3_acc: 0.9373 - val_dense_4_acc: 0.9791 - val_dense_5_acc: 0.9836
# Epoch 7/30
# 180/180 [==============================] - 70s 391ms/step - loss: 0.4711 - dense_3_loss: 0.2474 - dense_4_loss: 0.1307 - dense_5_loss: 0.0931 - dense_3_acc: 0.9261 - dense_4_acc: 0.9606 - dense_5_acc: 0.9713 - val_loss: 0.3763 - val_dense_3_loss: 0.2363 - val_dense_4_loss: 0.0798 - val_dense_5_loss: 0.0602 - val_dense_3_acc: 0.9403 - val_dense_4_acc: 0.9808 - val_dense_5_acc: 0.9838
# Epoch 8/30
# 180/180 [==============================] - 70s 387ms/step - loss: 0.4619 - dense_3_loss: 0.2442 - dense_4_loss: 0.1305 - dense_5_loss: 0.0872 - dense_3_acc: 0.9266 - dense_4_acc: 0.9605 - dense_5_acc: 0.9730 - val_loss: 0.3884 - val_dense_3_loss: 0.2443 - val_dense_4_loss: 0.0825 - val_dense_5_loss: 0.0616 - val_dense_3_acc: 0.9328 - val_dense_4_acc: 0.9803 - val_dense_5_acc: 0.9828
# Epoch 9/30
# 180/180 [==============================] - 69s 381ms/step - loss: 0.4492 - dense_3_loss: 0.2306 - dense_4_loss: 0.1311 - dense_5_loss: 0.0876 - dense_3_acc: 0.9307 - dense_4_acc: 0.9616 - dense_5_acc: 0.9729 - val_loss: 0.4101 - val_dense_3_loss: 0.2460 - val_dense_4_loss: 0.0983 - val_dense_5_loss: 0.0659 - val_dense_3_acc: 0.9320 - val_dense_4_acc: 0.9764 - val_dense_5_acc: 0.9811
# Epoch 10/30
# 180/180 [==============================] - 68s 376ms/step - loss: 0.4308 - dense_3_loss: 0.2233 - dense_4_loss: 0.1216 - dense_5_loss: 0.0858 - dense_3_acc: 0.9311 - dense_4_acc: 0.9649 - dense_5_acc: 0.9734 - val_loss: 0.3778 - val_dense_3_loss: 0.2331 - val_dense_4_loss: 0.0825 - val_dense_5_loss: 0.0622 - val_dense_3_acc: 0.9358 - val_dense_4_acc: 0.9806 - val_dense_5_acc: 0.9843
# Epoch 11/30
# 180/180 [==============================] - 69s 386ms/step - loss: 0.4326 - dense_3_loss: 0.2211 - dense_4_loss: 0.1269 - dense_5_loss: 0.0847 - dense_3_acc: 0.9332 - dense_4_acc: 0.9617 - dense_5_acc: 0.9743 - val_loss: 0.4058 - val_dense_3_loss: 0.2428 - val_dense_4_loss: 0.0948 - val_dense_5_loss: 0.0682 - val_dense_3_acc: 0.9375 - val_dense_4_acc: 0.9786 - val_dense_5_acc: 0.9813
# Epoch 12/30
# 180/180 [==============================] - 67s 372ms/step - loss: 0.4165 - dense_3_loss: 0.2087 - dense_4_loss: 0.1253 - dense_5_loss: 0.0825 - dense_3_acc: 0.9358 - dense_4_acc: 0.9619 - dense_5_acc: 0.9739 - val_loss: 0.3904 - val_dense_3_loss: 0.2483 - val_dense_4_loss: 0.0810 - val_dense_5_loss: 0.0611 - val_dense_3_acc: 0.9358 - val_dense_4_acc: 0.9813 - val_dense_5_acc: 0.9831
# Epoch 13/30
# 180/180 [==============================] - 69s 382ms/step - loss: 0.4035 - dense_3_loss: 0.2057 - dense_4_loss: 0.1199 - dense_5_loss: 0.0779 - dense_3_acc: 0.9374 - dense_4_acc: 0.9645 - dense_5_acc: 0.9762 - val_loss: 0.4001 - val_dense_3_loss: 0.2503 - val_dense_4_loss: 0.0861 - val_dense_5_loss: 0.0637 - val_dense_3_acc: 0.9363 - val_dense_4_acc: 0.9793 - val_dense_5_acc: 0.9826
# Epoch 14/30
# 180/180 [==============================] - 66s 365ms/step - loss: 0.3955 - dense_3_loss: 0.2014 - dense_4_loss: 0.1148 - dense_5_loss: 0.0793 - dense_3_acc: 0.9376 - dense_4_acc: 0.9655 - dense_5_acc: 0.9752 - val_loss: 0.3984 - val_dense_3_loss: 0.2624 - val_dense_4_loss: 0.0780 - val_dense_5_loss: 0.0580 - val_dense_3_acc: 0.9338 - val_dense_4_acc: 0.9818 - val_dense_5_acc: 0.9841
# Epoch 15/30
# 180/180 [==============================] - 69s 382ms/step - loss: 0.3932 - dense_3_loss: 0.2007 - dense_4_loss: 0.1168 - dense_5_loss: 0.0757 - dense_3_acc: 0.9374 - dense_4_acc: 0.9645 - dense_5_acc: 0.9759 - val_loss: 0.3743 - val_dense_3_loss: 0.2391 - val_dense_4_loss: 0.0731 - val_dense_5_loss: 0.0622 - val_dense_3_acc: 0.9422 - val_dense_4_acc: 0.9846 - val_dense_5_acc: 0.9833
# Epoch 16/30
# 180/180 [==============================] - 67s 371ms/step - loss: 0.3749 - dense_3_loss: 0.1876 - dense_4_loss: 0.1120 - dense_5_loss: 0.0753 - dense_3_acc: 0.9417 - dense_4_acc: 0.9652 - dense_5_acc: 0.9766 - val_loss: 0.4120 - val_dense_3_loss: 0.2529 - val_dense_4_loss: 0.0874 - val_dense_5_loss: 0.0717 - val_dense_3_acc: 0.9388 - val_dense_4_acc: 0.9788 - val_dense_5_acc: 0.9808
# Epoch 17/30
# 180/180 [==============================] - 64s 356ms/step - loss: 0.3839 - dense_3_loss: 0.1898 - dense_4_loss: 0.1154 - dense_5_loss: 0.0788 - dense_3_acc: 0.9413 - dense_4_acc: 0.9643 - dense_5_acc: 0.9757 - val_loss: 0.3820 - val_dense_3_loss: 0.2299 - val_dense_4_loss: 0.0919 - val_dense_5_loss: 0.0602 - val_dense_3_acc: 0.9415 - val_dense_4_acc: 0.9766 - val_dense_5_acc: 0.9808
# Epoch 18/30
# 180/180 [==============================] - 67s 374ms/step - loss: 0.3664 - dense_3_loss: 0.1821 - dense_4_loss: 0.1101 - dense_5_loss: 0.0743 - dense_3_acc: 0.9434 - dense_4_acc: 0.9667 - dense_5_acc: 0.9769 - val_loss: 0.4291 - val_dense_3_loss: 0.2462 - val_dense_4_loss: 0.1196 - val_dense_5_loss: 0.0633 - val_dense_3_acc: 0.9375 - val_dense_4_acc: 0.9724 - val_dense_5_acc: 0.9828
# Epoch 19/30
# 180/180 [==============================] - 67s 374ms/step - loss: 0.3624 - dense_3_loss: 0.1846 - dense_4_loss: 0.1079 - dense_5_loss: 0.0700 - dense_3_acc: 0.9438 - dense_4_acc: 0.9679 - dense_5_acc: 0.9780 - val_loss: 0.4267 - val_dense_3_loss: 0.2437 - val_dense_4_loss: 0.1155 - val_dense_5_loss: 0.0675 - val_dense_3_acc: 0.9380 - val_dense_4_acc: 0.9711 - val_dense_5_acc: 0.9816
# Epoch 20/30
# 180/180 [==============================] - 67s 374ms/step - loss: 0.3568 - dense_3_loss: 0.1750 - dense_4_loss: 0.1096 - dense_5_loss: 0.0723 - dense_3_acc: 0.9454 - dense_4_acc: 0.9666 - dense_5_acc: 0.9776 - val_loss: 0.3964 - val_dense_3_loss: 0.2495 - val_dense_4_loss: 0.0837 - val_dense_5_loss: 0.0631 - val_dense_3_acc: 0.9390 - val_dense_4_acc: 0.9803 - val_dense_5_acc: 0.9828
# Epoch 21/30
# 180/180 [==============================] - 64s 356ms/step - loss: 0.3423 - dense_3_loss: 0.1660 - dense_4_loss: 0.1090 - dense_5_loss: 0.0673 - dense_3_acc: 0.9487 - dense_4_acc: 0.9672 - dense_5_acc: 0.9788 - val_loss: 0.4070 - val_dense_3_loss: 0.2467 - val_dense_4_loss: 0.0894 - val_dense_5_loss: 0.0709 - val_dense_3_acc: 0.9373 - val_dense_4_acc: 0.9796 - val_dense_5_acc: 0.9803
# Epoch 22/30
# 180/180 [==============================] - 67s 372ms/step - loss: 0.3453 - dense_3_loss: 0.1695 - dense_4_loss: 0.1066 - dense_5_loss: 0.0691 - dense_3_acc: 0.9480 - dense_4_acc: 0.9680 - dense_5_acc: 0.9786 - val_loss: 0.4576 - val_dense_3_loss: 0.2519 - val_dense_4_loss: 0.1418 - val_dense_5_loss: 0.0640 - val_dense_3_acc: 0.9388 - val_dense_4_acc: 0.9627 - val_dense_5_acc: 0.9833
# Epoch 23/30
# 180/180 [==============================] - 67s 371ms/step - loss: 0.3483 - dense_3_loss: 0.1728 - dense_4_loss: 0.1067 - dense_5_loss: 0.0687 - dense_3_acc: 0.9474 - dense_4_acc: 0.9679 - dense_5_acc: 0.9790 - val_loss: 0.4080 - val_dense_3_loss: 0.2642 - val_dense_4_loss: 0.0917 - val_dense_5_loss: 0.0522 - val_dense_3_acc: 0.9330 - val_dense_4_acc: 0.9783 - val_dense_5_acc: 0.9853
# Epoch 24/30
# 180/180 [==============================] - 67s 370ms/step - loss: 0.3364 - dense_3_loss: 0.1666 - dense_4_loss: 0.1027 - dense_5_loss: 0.0672 - dense_3_acc: 0.9494 - dense_4_acc: 0.9683 - dense_5_acc: 0.9790 - val_loss: 0.3947 - val_dense_3_loss: 0.2603 - val_dense_4_loss: 0.0795 - val_dense_5_loss: 0.0549 - val_dense_3_acc: 0.9358 - val_dense_4_acc: 0.9806 - val_dense_5_acc: 0.9853
# Epoch 25/30
# 180/180 [==============================] - 62s 347ms/step - loss: 0.3262 - dense_3_loss: 0.1622 - dense_4_loss: 0.0991 - dense_5_loss: 0.0649 - dense_3_acc: 0.9503 - dense_4_acc: 0.9699 - dense_5_acc: 0.9791 - val_loss: 0.3771 - val_dense_3_loss: 0.2408 - val_dense_4_loss: 0.0814 - val_dense_5_loss: 0.0549 - val_dense_3_acc: 0.9408 - val_dense_4_acc: 0.9823 - val_dense_5_acc: 0.9833
# Epoch 26/30
# 180/180 [==============================] - 67s 374ms/step - loss: 0.3146 - dense_3_loss: 0.1533 - dense_4_loss: 0.0983 - dense_5_loss: 0.0629 - dense_3_acc: 0.9520 - dense_4_acc: 0.9701 - dense_5_acc: 0.9798 - val_loss: 0.3868 - val_dense_3_loss: 0.2451 - val_dense_4_loss: 0.0915 - val_dense_5_loss: 0.0503 - val_dense_3_acc: 0.9390 - val_dense_4_acc: 0.9754 - val_dense_5_acc: 0.9861
# Epoch 27/30
# 180/180 [==============================] - 64s 356ms/step - loss: 0.3126 - dense_3_loss: 0.1536 - dense_4_loss: 0.0948 - dense_5_loss: 0.0642 - dense_3_acc: 0.9528 - dense_4_acc: 0.9715 - dense_5_acc: 0.9799 - val_loss: 0.3945 - val_dense_3_loss: 0.2518 - val_dense_4_loss: 0.0846 - val_dense_5_loss: 0.0581 - val_dense_3_acc: 0.9398 - val_dense_4_acc: 0.9788 - val_dense_5_acc: 0.9853
# Epoch 28/30
# 180/180 [==============================] - 60s 335ms/step - loss: 0.3127 - dense_3_loss: 0.1548 - dense_4_loss: 0.0955 - dense_5_loss: 0.0624 - dense_3_acc: 0.9512 - dense_4_acc: 0.9713 - dense_5_acc: 0.9809 - val_loss: 0.4343 - val_dense_3_loss: 0.2564 - val_dense_4_loss: 0.1137 - val_dense_5_loss: 0.0641 - val_dense_3_acc: 0.9370 - val_dense_4_acc: 0.9716 - val_dense_5_acc: 0.9821
# Epoch 29/30
# 180/180 [==============================] - 66s 364ms/step - loss: 0.3121 - dense_3_loss: 0.1533 - dense_4_loss: 0.0964 - dense_5_loss: 0.0625 - dense_3_acc: 0.9517 - dense_4_acc: 0.9726 - dense_5_acc: 0.9801 - val_loss: 0.4022 - val_dense_3_loss: 0.2501 - val_dense_4_loss: 0.0890 - val_dense_5_loss: 0.0631 - val_dense_3_acc: 0.9378 - val_dense_4_acc: 0.9791 - val_dense_5_acc: 0.9841
# Epoch 30/30
# 180/180 [==============================] - 65s 362ms/step - loss: 0.3038 - dense_3_loss: 0.1476 - dense_4_loss: 0.0966 - dense_5_loss: 0.0595 - dense_3_acc: 0.9545 - dense_4_acc: 0.9706 - dense_5_acc: 0.9816 - val_loss: 0.4038 - val_dense_3_loss: 0.2601 - val_dense_4_loss: 0.0831 - val_dense_5_loss: 0.0607 - val_dense_3_acc: 0.9383 - val_dense_4_acc: 0.9796 - val_dense_5_acc: 0.9838

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_acc'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_acc'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_acc'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_acc'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_acc'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_acc'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 41138

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('../data/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample
# Out:
#                          row_id  target
# 0    Test_0_consonant_diacritic       0
# 1          Test_0_grapheme_root       3
# 2        Test_0_vowel_diacritic       0
# 3    Test_1_consonant_diacritic       0
# 4          Test_1_grapheme_root      93
# 5        Test_1_vowel_diacritic       2
# 6    Test_2_consonant_diacritic       0
# 7          Test_2_grapheme_root      19
# 8        Test_2_vowel_diacritic       0
# 9    Test_3_consonant_diacritic       0
# 10         Test_3_grapheme_root     115
# 11       Test_3_vowel_diacritic       0
# 12   Test_4_consonant_diacritic       0
# 13         Test_4_grapheme_root      55
# 14       Test_4_vowel_diacritic       4
# 15   Test_5_consonant_diacritic       0
# 16         Test_5_grapheme_root     115
# 17       Test_5_vowel_diacritic       2
# 18   Test_6_consonant_diacritic       5
# 19         Test_6_grapheme_root     147
# 20       Test_6_vowel_diacritic       9
# 21   Test_7_consonant_diacritic       0
# 22         Test_7_grapheme_root     137
# 23       Test_7_vowel_diacritic       7
# 24   Test_8_consonant_diacritic       0
# 25         Test_8_grapheme_root     119
# 26       Test_8_vowel_diacritic       9
# 27   Test_9_consonant_diacritic       0
# 28         Test_9_grapheme_root     133
# 29       Test_9_vowel_diacritic      10
# 30  Test_10_consonant_diacritic       4
# 31        Test_10_grapheme_root     148
# 32      Test_10_vowel_diacritic       1
# 33  Test_11_consonant_diacritic       0
# 34        Test_11_grapheme_root      21
# 35      Test_11_vowel_diacritic       2
