# %%
import numpy as np
import pandas as pd
import os

"""
This will load a csv file and return a pandas dataframe
@input: filepath:: string :: filepath of csv file
@input: names:: list :: column names list 
"""
def load_csv(filepath, names=None):
    filepath =  os.path.abspath(filepath)
    if os.path.exists(filepath):
        df = pd.read_csv(filepath, sep=",", names=names, encoding='utf-8')
        return df
    
    return None

# %%
class_map_path = "data/class_map.csv"
train_data_path = "data/train.csv"
test_data_path = "data/test.csv"

class_df = load_csv(class_map_path)
class_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
grapheme_roots = class_df[class_df["component_type"] == "grapheme_root"]
grapheme_roots.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
vowel_diacritic = class_df[class_df["component_type"] == "vowel_diacritic"]
vowel_diacritic.head()
# Out:
#       component_type  label component
# 168  vowel_diacritic      0         0
# 169  vowel_diacritic      1         া
# 170  vowel_diacritic      2         ি
# 171  vowel_diacritic      3         ী
# 172  vowel_diacritic      4         ু

# %%
consonant_diacritic = class_df[class_df["component_type"] == "consonant_diacritic"]
consonant_diacritic.head()
# Out:
#           component_type  label component
# 179  consonant_diacritic      0         0
# 180  consonant_diacritic      1         ঁ
# 181  consonant_diacritic      2        র্
# 182  consonant_diacritic      3       র্য
# 183  consonant_diacritic      4        ্য

# %%
train_df = load_csv(train_data_path)
train_df
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 0            Train_0             15                9                    5
# 1            Train_1            159                0                    0
# 2            Train_2             22                3                    5
# 3            Train_3             53                2                    2
# 4            Train_4             71                9                    5
# ...              ...            ...              ...                  ...
# 200835  Train_200835             22                7                    2
# 200836  Train_200836             65                9                    0
# 200837  Train_200837              2                1                    4
# 200838  Train_200838            152                9                    0
# 200839  Train_200839            127                2                    0
#
#        grapheme
# 0        ক্ট্রো
# 1             হ
# 2          খ্রী
# 3          র্টি
# 4          থ্রো
# ...         ...
# 200835     র্খে
# 200836     ত্তো
# 200837     অ্যা
# 200838     স্নো
# 200839     ল্টি
#
# [200840 rows x 5 columns]

# %%
train_df[train_df["image_id"]=="Train_200835"]
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 200835  Train_200835             22                7                    2
#
#        grapheme
# 200835     র্খে

# %%
merged_df = train_df.merge(grapheme_roots, how ="outer", left_on="grapheme_root", right_on="label")
merged_df = merged_df.drop(columns=["component_type", "label"])
merged_df = merged_df.rename(columns={"component": "grapheme_component"})
merged_df
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 0            Train_0             15                9                    5
# 1          Train_111             15                0                    0
# 2          Train_137             15                9                    5
# 3          Train_431             15                9                    5
# 4          Train_503             15                9                    5
# ...              ...            ...              ...                  ...
# 200835  Train_191632             12                0                    0
# 200836  Train_195613             12                0                    0
# 200837  Train_196430             12                0                    0
# 200838  Train_197200             12                0                    0
# 200839  Train_199415             12                0                    0
#
#        grapheme grapheme_component
# 0        ক্ট্রো                ক্ট
# 1           ক্ট                ক্ট
# 2        ক্ট্রো                ক্ট
# 3        ক্ট্রো                ক্ট
# 4        ক্ট্রো                ক্ট
# ...         ...                ...
# 200835        ঔ                  ঔ
# 200836        ঔ                  ঔ
# 200837        ঔ                  ঔ
# 200838        ঔ                  ঔ
# 200839        ঔ                  ঔ
#
# [200840 rows x 6 columns]

# %%
merged_df = merged_df.merge(vowel_diacritic, how ="outer", left_on="vowel_diacritic", right_on="label")
merged_df = merged_df.drop(columns=["component_type", "label"])
merged_df = merged_df.rename(columns={"component": "vowel_diacritic_component"})
merged_df
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 0            Train_0             15                9                    5
# 1          Train_137             15                9                    5
# 2          Train_431             15                9                    5
# 3          Train_503             15                9                    5
# 4         Train_1094             15                9                    5
# ...              ...            ...              ...                  ...
# 200835  Train_192215            113               10                    0
# 200836  Train_194690            113               10                    0
# 200837  Train_197446            113               10                    0
# 200838  Train_198791            113               10                    0
# 200839  Train_200651            113               10                    0
#
#        grapheme grapheme_component vowel_diacritic_component
# 0        ক্ট্রো                ক্ট                         ো
# 1        ক্ট্রো                ক্ট                         ো
# 2        ক্ট্রো                ক্ট                         ো
# 3        ক্ট্রো                ক্ট                         ো
# 4        ক্ট্রো                ক্ট                         ো
# ...         ...                ...                       ...
# 200835       ভৌ                  ভ                         ৌ
# 200836       ভৌ                  ভ                         ৌ
# 200837       ভৌ                  ভ                         ৌ
# 200838       ভৌ                  ভ                         ৌ
# 200839       ভৌ                  ভ                         ৌ
#
# [200840 rows x 7 columns]

# %%
merged_df = merged_df.merge(consonant_diacritic, how ="outer", left_on="consonant_diacritic", right_on="label")
merged_df = merged_df.drop(columns=["component_type", "label"])
merged_df = merged_df.rename(columns={"component": "consonant_diacritic_component"})
merged_df
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 0            Train_0             15                9                    5
# 1          Train_137             15                9                    5
# 2          Train_431             15                9                    5
# 3          Train_503             15                9                    5
# 4         Train_1094             15                9                    5
# ...              ...            ...              ...                  ...
# 200835  Train_196244            149                1                    6
# 200836  Train_196753            149                1                    6
# 200837  Train_197765            149                1                    6
# 200838  Train_199265            149                1                    6
# 200839  Train_199374            149                1                    6
#
#         grapheme grapheme_component vowel_diacritic_component  \
# 0         ক্ট্রো                ক্ট                         ো
# 1         ক্ট্রো                ক্ট                         ো
# 2         ক্ট্রো                ক্ট                         ো
# 3         ক্ট্রো                ক্ট                         ো
# 4         ক্ট্রো                ক্ট                         ো
# ...          ...                ...                       ...
# 200835  স্ট্র্যা                স্ট                         া
# 200836  স্ট্র্যা                স্ট                         া
# 200837  স্ট্র্যা                স্ট                         া
# 200838  স্ট্র্যা                স্ট                         া
# 200839  স্ট্র্যা                স্ট                         া
#
#        consonant_diacritic_component
# 0                                 ্র
# 1                                 ্র
# 2                                 ্র
# 3                                 ্র
# 4                                 ্র
# ...                              ...
# 200835                          ্র্য
# 200836                          ্র্য
# 200837                          ্র্য
# 200838                          ্র্য
# 200839                          ্র্য
#
# [200840 rows x 8 columns]

# %%
merged_df
